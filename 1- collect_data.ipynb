# %%
import os
import cv2
DATA_DIR = './data'
if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)

number_of_classes = 43
dataset_size = 100

cap = cv2.VideoCapture(0)
for j in range(number_of_classes):
    if not os.path.exists(os.path.join(DATA_DIR, str(j))):
        os.makedirs(os.path.join(DATA_DIR, str(j)))

    print('Collecting data for class {}'.format(j))

    
    while True:
        ret, frame = cap.read()
        cv2.putText(frame, 'Ready? Press "Q" ! :)', (100, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3,
                    cv2.LINE_AA)
        cv2.imshow('frame', frame)
        if cv2.waitKey(1) == ord('q'):
            break

    counter = 0
    while counter < dataset_size:
        ret, frame = cap.read()
        cv2.imshow('frame', frame)
        cv2.waitKey(1)
        cv2.imwrite(os.path.join(DATA_DIR, str(j), '{}.jpg'.format(counter)), frame)
        counter += 1

cap.release()
cv2.destroyAllWindows()

# %%
# Out:
# C:\Users\Borse\AppData\Local\Temp\ipykernel_11604\1969196819.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   class_label = row[0]
# Saved image ./data\6\0.jpg
# Saved image ./data\5\1.jpg
# Saved image ./data\10\2.jpg
# Saved image ./data\0\3.jpg
# Saved image ./data\3\4.jpg
# Saved image ./data\21\5.jpg
# Saved image ./data\10\6.jpg
# Saved image ./data\14\7.jpg
# Saved image ./data\3\8.jpg
# Saved image ./data\7\9.jpg
# Saved image ./data\8\10.jpg
# Saved image ./data\8\11.jpg
# Saved image ./data\21\12.jpg
# Saved image ./data\12\13.jpg
# Saved image ./data\7\14.jpg
# Saved image ./data\4\15.jpg
# Saved image ./data\22\16.jpg
# Saved image ./data\0\17.jpg
# Saved image ./data\7\18.jpg
# Saved image ./data\7\19.jpg
# Saved image ./data\2\20.jpg
# Saved image ./data\0\21.jpg
# ...

# %%
import os
import cv2

# Define the data directory
DATA_DIR = './data'
if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)

# Define the label to collect data for
label_to_collect = 42
dataset_size = 100

# Create a directory for the specified label if it doesn't exist
label_dir = os.path.join(DATA_DIR, str(label_to_collect))
if not os.path.exists(label_dir):
    os.makedirs(label_dir)

# Start video capture
cap = cv2.VideoCapture(0)

print('Collecting data for class {}'.format(label_to_collect))

# Wait for the user to be ready
while True:
    ret, frame = cap.read()
    cv2.putText(frame, 'Ready? Press "Q" to start collecting data!', (100, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3,
                cv2.LINE_AA)
    cv2.imshow('frame', frame)
    if cv2.waitKey(1) == ord('q'):
        break

counter = 0
while counter < dataset_size:
    ret, frame = cap.read()
    cv2.imshow('frame', frame)
    
    # Save the frame to the directory for label 42
    cv2.imwrite(os.path.join(label_dir, '{}.jpg'.format(counter)), frame)
    counter += 1
    cv2.waitKey(1)

# Release resources
cap.release()
cv2.destroyAllWindows()

print(f"Data collection for class {label_to_collect} complete. Collected {dataset_size} images.")
# Out:
# ...
# Data collection for class 42 complete. Collected 100 images.
